# %% [markdown]
# <a href="https://colab.research.google.com/github/SACHINSIROHI47/DataScience_with_Python_Programming_Project/blob/main/Apple_Stock_Analysis_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Stock Market Analysis Project**

# %%
#load library yfinance
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


#load live data Apple Inc. (AAPL)
apple = yf.Ticker("AAPL")
apple_data = apple.history(period="1y")
apple_data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-10-19 00:00:00-04:00  175.143776  176.934615  174.298112  174.566742
# 2023-10-20 00:00:00-04:00  174.417484  174.526925  171.761079  171.999863
# 2023-10-23 00:00:00-04:00  170.039906  173.124115  169.064885  172.119263
# 2023-10-24 00:00:00-04:00  172.168993  172.785832  170.577133  172.557007
# 2023-10-25 00:00:00-04:00  171.004971  172.178956  169.781222  170.228943
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-10-19 00:00:00-04:00  59302900        0.0           0.0
# 2023-10-20 00:00:00-04:00  64189300        0.0           0.0
# 2023-10-23 00:00:00-04:00  55980100        0.0           0.0
# 2023-10-24 00:00:00-04:00  43816600        0.0           0.0
# 2023-10-25 00:00:00-04:00  57157000        0.0           0.0

# %%
stockdata=yf.download('AAPL',start='2020-01-01',end='2023-01-01')
stockdata.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.876099  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.167610  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.742653  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.400536  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.565193  132079200

# %%
#reset the index
#inplace true use for permanently

stockdata.reset_index(inplace=True)
stockdata.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.876099  135480400
# 1 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.167610  146322800
# 2 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.742653  118387200
# 3 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.400536  108872000
# 4 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.565193  132079200

# %%
#using date as feature
stockdata['Days']=(stockdata['Date']-stockdata['Date'].min()).dt.days
stockdata.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.876099
# 1 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.167610
# 2 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.742653
# 3 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.400536
# 4 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.565193
#
#       Volume  Days
# 0  135480400     0
# 1  146322800     1
# 2  118387200     4
# 3  108872000     5
# 4  132079200     6

# %%
#define the x and y target
x=stockdata[['Days']]
y=stockdata['Close']

#split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#show shape of data with label message
print('Shape of x_train:',x_train.shape)
print('Shape of x_test:',x_test.shape)
print('Shape of y_train:',y_train.shape)
print('Shape of y_test:',y_test.shape)
# Out:
# Shape of x_train: (604, 1)
# Shape of x_test: (152, 1)
# Shape of y_train: (604,)
# Shape of y_test: (152,)

# %%
#apply the linear regression model
model=LinearRegression()
model.fit(x_train,y_train)

#make prediction
y_pred=model.predict(x_test)


#visualise the actual vs predicted stock prices
plt.figure(figsize=(10,6))
plt.scatter(x_test,y_test,color='blue',label='Actual Prices')
plt.plot(x_test,y_pred,color='red',linewidth=2,label='Predicted Prices')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.title('Apple Stock Price Prediction')
plt.legend()
plt.show()
