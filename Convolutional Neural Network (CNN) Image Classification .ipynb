# %% [markdown]
# <a href="https://colab.research.google.com/github/SACHINSIROHI47/DataScience_with_Python_Programming_Project/blob/main/Convolutional%20Neural%20Network%20(CNN)%20Image%20Classification%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**What is CNN in Python**
#
# A Convolutional Neural Network (CNN) is a type of deep neural network used for image recognition and classification tasks in machine learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#CIFAR Dataset Image Classification using CNN
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
#Load cifar10 dataset
data=tf.keras.datasets.cifar10
(x_train,y_train),(x_test,y_test)=data.load_data()
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
labels=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
fig,axes=plt.subplots(5,5,figsize=(10,10))
index=0
for i in range(5):
  for j in range(5):
    axes[i,j].set_title(labels[y_train[index][0]])
    axes[i,j].imshow(x_train[index])
    axes[i,j].axis('off')
    index+=1
plt.show()
